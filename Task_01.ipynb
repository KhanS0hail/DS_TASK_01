# %% [markdown]
# # DS_Task_01
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Reading CSV file

# %%
df=pd.read_csv("worldpopulationdata.csv")

# %% [markdown]
# #### Displaying top 3 Columns

# %%
df.head(3) #data of top 3 rows
# Out:
#          Series Name  Series Code Country Name Country Code        2022
# 0  Population, total  SP.POP.TOTL  Afghanistan          AFG  41128771.0  \
# 1  Population, total  SP.POP.TOTL      Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL      Algeria          DZA  44903225.0
#
#          2021        2020        2019        2018        2017  ...
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...  \
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
#
#          2010        2009        2008        2007        2006        2005
# 0  28189672.0  27385307.0  26427199.0  25903301.0  25442944.0  24411191.0  \
# 1   2913021.0   2927519.0   2947314.0   2970017.0   2992547.0   3011487.0
# 2  35856344.0  35196037.0  34569592.0  33983827.0  33435080.0  32956690.0
#
#          2004        2003        2002        2001
# 0  23553551.0  22645130.0  21000256.0  19688632.0
# ...

# %% [markdown]
# #### Displaying bottom 3 Columns

# %%
df.tail(3) #data of bottom 3 rows
# Out:
#                                    Series Name        Series Code
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS  \
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#      Country Name Country Code       2022       2021       2020       2019
# 1082  Yemen, Rep.          YEM  50.519031  50.538516  50.554317  50.571320  \
# 1083       Zambia          ZMB  49.344602  49.344951  49.338301  49.326233
# 1084     Zimbabwe          ZWE  47.214139  47.167153  47.130679  47.099796
#
#            2018       2017  ...       2010       2009       2008       2007
# 1082  50.596614  50.616964  ...  50.594170  50.582692  50.568876  50.553633  \
# 1083  49.309087  49.288400  ...  49.056379  48.981404  48.888443  48.784780
# 1084  47.076238  47.051613  ...  46.995893  47.049546  47.106068  47.166435
#
#            2006       2005       2004       2003       2002       2001
# ...

# %%
df.shape
# Out:
# (1085, 26)

# %% [markdown]
# #### Printing Columns Name

# %%
df.columns #printing columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# #### Dataset info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  \
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  \
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# #### Checking Duplicates

# %%
df.duplicated().sum() #number od duplicte data
# Out:
# 0

# %% [markdown]
# #### Checking Missing Value

# %%
df.isna().sum().sum() #returns total number of missing value
# Out:
# 0

# %% [markdown]
# #### Unique values for columns

# %%
print(df["Country Name"].unique())
print("\n No. of Unique Country",df["Country Name"].nunique()) #No. of Unique Country
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print("\n Total no of unique country code:",df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %%
df['Series Name'].unique()
# Out:
# array(['Population, total', 'Population, female', 'Population, male',
#        'Population, female (% of total population)',
#        'Population, male (% of total population)'], dtype=object)

# %%
df['Series Code'].unique()
# Out:
# array(['SP.POP.TOTL', 'SP.POP.TOTL.FE.IN', 'SP.POP.TOTL.MA.IN',
#        'SP.POP.TOTL.FE.ZS', 'SP.POP.TOTL.MA.ZS'], dtype=object)

# %% [markdown]
# #### Dropping columns which are not important

# %%
df.drop(['Series Name','Country Code'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Series Code', 'Country Name', '2022', '2021', '2020', '2019', '2018',
#        '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001'],
#       dtype='object')

# %%
n=df['Series Code'].unique()
n
# Out:
# array(['SP.POP.TOTL', 'SP.POP.TOTL.FE.IN', 'SP.POP.TOTL.MA.IN',
#        'SP.POP.TOTL.FE.ZS', 'SP.POP.TOTL.MA.ZS'], dtype=object)

# %% [markdown]
# #### Top ten country with respect to total population

# %%
total_pop_data = df[df['Series Code'] == 'SP.POP.TOTL']

# %%
total_pop_sorted = total_pop_data.sort_values(by="2022", ascending=False)
total_top_ten_countries = total_pop_sorted.head(10)
print("Top ten countries of total population\n")
total_top_ten_countries[['Country Name']]
# Out:
# Top ten countries of total population
#            Country Name
# 89                India
# 41                China
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 144             Nigeria
# 26               Brazil
# 15           Bangladesh
# 161  Russian Federation
# 127              Mexico

# %% [markdown]
# # Bar Plot

# %% [markdown]
# Top ten countries of total population in year 2022 and 2012

# %%
plt.figure(figsize=(12, 5))
plt.subplot(2,2,1)
sns.barplot(x="2022", y="Country Name", data=total_top_ten_countries,hue="Country Name",palette="rocket")
plt.title("Top Ten Countries of Total Population (2022)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

plt.figure(figsize=(12, 5))
plt.subplot(2,2,2)
sns.barplot(x="2012", y="Country Name", data=total_top_ten_countries,hue="Country Name",palette="rocket")
plt.title("Top Ten Countries with Total Population (2012)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

# %% [markdown]
# Top ten countries of total population in year 2010 and 2001

# %%
plt.figure(figsize=(12, 5))
plt.subplot(2,2,1)
sns.barplot(x="2010", y="Country Name", data=total_top_ten_countries,hue="Country Name",palette="rocket")
plt.title("Top Ten Countries of Total Population (2010)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

plt.figure(figsize=(12, 5))
plt.subplot(2,2,2)
sns.barplot(x="2001", y="Country Name", data=total_top_ten_countries,hue="Country Name",palette="rocket")
plt.title("Top Ten Countries with Total Population (2001)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

# %% [markdown]
# Comparison of total pop in year 2001 and 2022 of top ten countries

# %%
width = 0.4  # Adjusted width to fit the bars better
year2022 = total_top_ten_countries["2022"]
year2001 = total_top_ten_countries["2001"]
country = total_top_ten_countries['Country Name']
values = np.arange(len(country))

plt.figure(figsize=(20, 12))
plt.bar(values, year2001, width=width, label='2001', color='maroon')
plt.bar(values + width, year2022, width=width, label='2022', color='salmon')

plt.xlabel('Country Name',fontsize=12)
plt.ylabel('Total Population',fontsize=12)
plt.title('Comparison of Total Population in 2001 and 2022 for Top Ten Countries',fontsize=15,fontweight='bold')
plt.xticks(values, country, rotation=45, ha='right')
plt.legend()
plt.show()

# %% [markdown]
# Extraction of bottom-10 countries with respect to total population

# %%
total_pop_data=total_pop_data.sort_values(by="2022",ascending=True)
bottom_ten_countries=total_pop_data.head(10)
print("Bottom Ten Countries  of total population\n")
bottom_ten_countries[['Country Name']]
# Out:
# Bottom Ten Countries  of total population
#                  Country Name
# 201                    Tuvalu
# 137                     Nauru
# 150                     Palau
# 27     British Virgin Islands
# 183  St. Martin (French part)
# 75                  Gibraltar
# 164                San Marino
# 130                    Monaco
# 114             Liechtenstein
# 124          Marshall Islands

# %% [markdown]
# Bottom ten countries of total population in year 2022 and 2016

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,2,1)
sns.barplot(x="2022", y="Country Name", data=bottom_ten_countries,hue="Country Name",palette="spring")
plt.title("Bottom Ten Countries with Total Population (2022)",fontsize=10,fontweight='bold')
plt.xlabel("Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

plt.figure(figsize=(12,5))
plt.subplot(2,2,2)
sns.barplot(x="2012", y="Country Name", data=bottom_ten_countries,hue="Country Name",palette="spring")
plt.title("Bottom Ten Countries with Total Population (2012)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

# %% [markdown]
# Bottom ten countries of total population in year 2010 and 2001

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,2,1)
sns.barplot(x="2010", y="Country Name", data=bottom_ten_countries,hue="Country Name",palette="spring")
plt.title("Bottom Ten Countries with Total Population (2010)",fontsize=10,fontweight='bold')
plt.xlabel("Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

plt.figure(figsize=(12,5))
plt.subplot(2,2,2)
sns.barplot(x="2001", y="Country Name", data=bottom_ten_countries,hue="Country Name",palette="spring")
plt.title("Bottom Ten Countries with Total Population (2001)",fontsize=10,fontweight='bold')
plt.xlabel("Total Population",fontsize=9)
plt.ylabel("Country",fontsize=9)
plt.show()

# %% [markdown]
# Comparison of total pop in year 2001 and 2022 of bottom ten countries

# %%
width = 0.4
year2022 = bottom_ten_countries["2022"]
year2001 = bottom_ten_countries["2001"]
country = bottom_ten_countries['Country Name']
values = np.arange(len(country))

plt.figure(figsize=(20, 12))
plt.bar(values, year2001, width=width, label='2001', color='deeppink')
plt.bar(values + width, year2022, width=width, label='2022', color='gold')

plt.xlabel('Country Name',fontsize=12)
plt.ylabel('Total Population',fontsize=12)
plt.title('Comparison of Total Population in 2001 and 2022 for Bottom Ten Countries',fontsize=15,fontweight='bold')
plt.xticks(values, country, rotation=45, ha='right')
plt.legend()
plt.show()

# %% [markdown]
# Extraction of top ten countries with highest male population

# %%
male_pop_data=df[df['Series Code']=='SP.POP.TOTL.MA.IN']
male_pop_sorted=male_pop_data.sort_values(by="2022",ascending=False)
top_ten_male_pop_country=male_pop_sorted.head(10)
top_ten_male_pop_country[['Country Name']]
# Out:
#            Country Name
# 523               India
# 475               China
# 640       United States
# 524           Indonesia
# 583            Pakistan
# 578             Nigeria
# 460              Brazil
# 449          Bangladesh
# 595  Russian Federation
# 561              Mexico

# %% [markdown]
# Extraction of top ten countries with highest female population

# %%
female_pop_data=df[df['Series Code']=='SP.POP.TOTL.FE.IN']
female_pop_sorted=female_pop_data.sort_values(by="2022",ascending=False)
top_ten_female_pop_country=female_pop_sorted.head(10)
top_ten_female_pop_country[['Country Name']]
# Out:
#            Country Name
# 258               China
# 306               India
# 423       United States
# 307           Indonesia
# 366            Pakistan
# 243              Brazil
# 361             Nigeria
# 232          Bangladesh
# 378  Russian Federation
# 344              Mexico

# %% [markdown]
# Top ten countries with highest male and female population in 2022

# %%
plt.figure(figsize=(12,5))
plt.subplot(2,2,2)
sns.barplot(x="2022",y="Country Name",data=top_ten_male_pop_country,hue="Country Name",palette="Blues")
plt.title("TOp Ten Countries with Highest Male Polpulation (2022)",fontsize=10)
plt.ylabel("Country")
plt.xlabel("Male Population")
plt.show()

plt.figure(figsize=(12,5))
plt.subplot(2,2,2)
sns.barplot(x="2022",y="Country Name",data=top_ten_female_pop_country,hue="Country Name",palette="RdPu")
plt.title("TOp Ten Countries with Highest Female Polpulation (2022)",fontsize=10)
plt.ylabel("Country")
plt.xlabel("Female Population")
plt.show()

# %% [markdown]
# Extraction of top ten countries with lowest male population

# %%
Bottom_ten_male_pop_country=male_pop_sorted.tail(10)
Bottom_ten_male_pop_country[['Country Name']]
# Out:
#                  Country Name
# 558          Marshall Islands
# 548             Liechtenstein
# 564                    Monaco
# 598                San Marino
# 509                 Gibraltar
# 617  St. Martin (French part)
# 461    British Virgin Islands
# 584                     Palau
# 571                     Nauru
# 635                    Tuvalu

# %% [markdown]
# Extraction of top ten countries with lowest male population

# %%
Bottom_ten_female_pop_country=female_pop_sorted.tail(10)
Bottom_ten_female_pop_country[['Country Name']]
# Out:
#                   Country Name
# 389  Sint Maarten (Dutch part)
# 331              Liechtenstein
# 347                     Monaco
# 381                 San Marino
# 400   St. Martin (French part)
# 292                  Gibraltar
# 244     British Virgin Islands
# 367                      Palau
# 354                      Nauru
# 418                     Tuvalu

# %% [markdown]
# Top ten countries with lowest male and female population in 2022

# %%
# Create the bar plot
plt.figure(figsize=(15, 6))
plt.subplot(2,2,1)
sns.barplot(x="2022", y="Country Name", data=Bottom_ten_male_pop_country,hue="Country Name", palette="Blues")
plt.title("Top Ten Countries with Lowest Male Population (2022)",size=10)
plt.xlabel("Male Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

plt.figure(figsize=(15, 6))
plt.subplot(2,2,2)
sns.barplot(x="2022", y="Country Name", data=Bottom_ten_female_pop_country,hue="Country Name", palette="RdPu")
plt.title("Top Ten Countries with Lowest Female Population (2022)",size=10)
plt.xlabel("Female Population",size=10)
plt.ylabel("Country",size=10)
plt.show()

# %% [markdown]
# #### Stacked Bar Plot
# Top 10 Countries with Male and Female Populations (2022)

# %%
merged_data = pd.merge(male_pop_data, female_pop_data, on="Country Name", suffixes=("_male", "_female"))

# %%
merged_data
# Out:
#       Series Code_male           Country Name   2022_male   2021_male
# 0    SP.POP.TOTL.MA.IN            Afghanistan  20766442.0  20254878.0  \
# 1    SP.POP.TOTL.MA.IN                Albania   1384548.0   1404454.0
# 2    SP.POP.TOTL.MA.IN                Algeria  22862237.0  22497244.0
# 3    SP.POP.TOTL.MA.IN         American Samoa     21873.0     22289.0
# 4    SP.POP.TOTL.MA.IN                Andorra     40786.0     40361.0
# ..                 ...                    ...         ...         ...
# 212  SP.POP.TOTL.MA.IN  Virgin Islands (U.S.)     49137.0     49510.0
# 213  SP.POP.TOTL.MA.IN     West Bank and Gaza   2516444.0   2455361.0
# 214  SP.POP.TOTL.MA.IN            Yemen, Rep.  17023203.0  16668432.0
# 215  SP.POP.TOTL.MA.IN                 Zambia   9877642.0   9609004.0
# 216  SP.POP.TOTL.MA.IN               Zimbabwe   7705601.0   7543690.0
#
#       2020_male   2019_male   2018_male   2017_male   2016_male   2015_male
# ...

# %%
merged_data["Total Population in 2022"]=merged_data["2022_male"]+merged_data["2022_female"]
merged_data.head()
# Out:
#     Series Code_male    Country Name   2022_male   2021_male   2020_male
# 0  SP.POP.TOTL.MA.IN     Afghanistan  20766442.0  20254878.0  19692301.0  \
# 1  SP.POP.TOTL.MA.IN         Albania   1384548.0   1404454.0   1419264.0
# 2  SP.POP.TOTL.MA.IN         Algeria  22862237.0  22497244.0  22132899.0
# 3  SP.POP.TOTL.MA.IN  American Samoa     21873.0     22289.0     22921.0
# 4  SP.POP.TOTL.MA.IN         Andorra     40786.0     40361.0     39615.0
#
#     2019_male   2018_male   2017_male   2016_male   2015_male  ...
# 0  19090409.0  18549862.0  18028696.0  17520861.0  17071446.0  ...  \
# 1   1428828.0   1435881.0   1440219.0   1442176.0   1444890.0  ...
# 2  21756903.0  21362603.0  20961313.0  20556314.0  20152232.0  ...
# 3     23535.0     24134.0     24701.0     25240.0     25739.0  ...
# 4     38842.0     38071.0     37380.0     36628.0     36188.0  ...
#
#    2009_female  2008_female  2007_female  2006_female  2005_female
# ...

# %%
merged_data=merged_data.sort_values(by="Total Population in 2022", ascending=False)
top_10_countries=merged_data.head(10)
top_10_countries[['Country Name']]
# Out:
#            Country Name
# 89                India
# 41                China
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 144             Nigeria
# 26               Brazil
# 15           Bangladesh
# 161  Russian Federation
# 127              Mexico

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country Name", y="2022_male", data=top_10_countries, color="blue", label="Female Population")
sns.barplot(x="Country Name", y="2022_female", data=top_10_countries, bottom=top_10_countries["2022_male"], color="deeppink", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# Bottom 10 Countries with Male and Female Populations (2022)

# %%
bottom_10_countries = merged_data.tail(10)
bottom_10_countries[['Country Name']]
# Out:
#                  Country Name
# 124          Marshall Islands
# 114             Liechtenstein
# 130                    Monaco
# 164                San Marino
# 75                  Gibraltar
# 183  St. Martin (French part)
# 27     British Virgin Islands
# 150                     Palau
# 137                     Nauru
# 201                    Tuvalu

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country Name", y="2022_male", data=bottom_10_countries, color="blue", label="Female Population")
sns.barplot(x="Country Name", y="2022_female", data=bottom_10_countries, bottom=bottom_10_countries["2022_male"], color="deeppink", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2022)")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
